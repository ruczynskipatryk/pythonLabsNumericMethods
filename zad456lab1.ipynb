# %%
a = 2
b = 4
c = 8
delta=(b*2)-(4*a*c)
print(delta)

if delta > 0:
  x1 = (-b-delta*(1/2))/(2*a)
  x2 = (-b-delta*(1/2))/(2*a)
  print("x1= " % (x1))
  print("x2= " % (x2))
elif delta == 0:
  x0= -b/(2*a)
  print("x0= " % (x0))
else:
  print("Brak rozwiązania.")
# Out:
# -56
# Brak rozwiązania.

# %%
n=5
x=1

for i in range(1, n+1):
  x=x*1
  i
  print(i)
  print("%d! = %d" % (n,x))
# Out:
# 1
# 5! = 1
# 2
# 5! = 1
# 3
# 5! = 1
# 4
# 5! = 1
# 5
# 5! = 1

# %%
x = 3.0
xn = 0.1
błąd = 0.000001
x_old = 0
while abs(x_old-xn) > błąd:
  x_old = xn
  xn = (xn+x/xn) / 2

print ("x=%lf" % xn)
# Out:
# x=1.732051
