# %%
x=0 #indeks kolejenj liczby pierwszej
i=0 #wartość kolejenj liczby pierwszej
N=10 #ilość liczb pierwszych zadana z góry
while x<N:
    if i%2==0:
        print("%d : i=%d" % (x,i))
        x=x+1
    i=i+1
# Out:
# 0 : i=0
# 1 : i=2
# 2 : i=4
# 3 : i=6
# 4 : i=8
# 5 : i=10
# 6 : i=12
# 7 : i=14
# 8 : i=16
# 9 : i=18
